# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 624

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
api_key = "be3e264cb040dab2ab5013d13c51bec8"
url = 'https://api.openweathermap.org/data/2.5/weather'

city_data = []

print("Beginning Data Retrieval")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    city_url = f"{url}?q={city}&appid={api_key}"

    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    record_count += 1

    try:
        city_weather = requests.get(city_url).json()

        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        city_data.append({
            "City": city,
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Date": city_date
        })
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | isle of lewis
# City not found. Skipping...
# Processing Record 2 of Set 1 | port-aux-francais
# Processing Record 3 of Set 1 | bethel
# Processing Record 4 of Set 1 | adamstown
# Processing Record 5 of Set 1 | nadi
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | new norfolk
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | algeciras
# Processing Record 10 of Set 1 | hanceville
# Processing Record 11 of Set 1 | iqaluit
# Processing Record 12 of Set 1 | hammerfest
# Processing Record 13 of Set 1 | tual
# Processing Record 14 of Set 1 | selfoss
# Processing Record 15 of Set 1 | grytviken
# Processing Record 16 of Set 1 | chonchi
# Processing Record 17 of Set 1 | kabare
# Processing Record 18 of Set 1 | edinburgh of the seven seas
# Processing Record 19 of Set 1 | blackmans bay
# Processing Record 20 of Set 1 | hithadhoo
# Processing Record 21 of Set 1 | talnakh
# Processing Record 22 of Set 1 | lihue
# Processing Record 23 of Set 1 | aasiaat
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | mejit
# Processing Record 26 of Set 1 | timimoun
# Processing Record 27 of Set 1 | tutoia
# Processing Record 28 of Set 1 | waitangi
# Processing Record 29 of Set 1 | olonkinbyen
# Processing Record 30 of Set 1 | enewetak
# Processing Record 31 of Set 1 | sao vicente
# Processing Record 32 of Set 1 | st. john's
# Processing Record 33 of Set 1 | panaba
# Processing Record 34 of Set 1 | hawaiian paradise park
# Processing Record 35 of Set 1 | nemuro
# Processing Record 36 of Set 1 | badger
# Processing Record 37 of Set 1 | xilin hot
# Processing Record 38 of Set 1 | fort bragg
# Processing Record 39 of Set 1 | novomalorossiyskaya
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | mugia
# Processing Record 42 of Set 1 | walvis bay
# Processing Record 43 of Set 1 | anadyr
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | the pas
# Processing Record 46 of Set 1 | whakatane
# Processing Record 47 of Set 1 | saipan
# Processing Record 48 of Set 1 | murray bridge
# Processing Record 49 of Set 1 | utrik
# Processing Record 50 of Set 1 | rio grande
# Processing Record 0 of Set 2 | glace bay
# Processing Record 1 of Set 2 | monticello
# Processing Record 2 of Set 2 | stanley
# Processing Record 3 of Set 2 | mantua
# Processing Record 4 of Set 2 | portland
# Processing Record 5 of Set 2 | yangor
# City not found. Skipping...
# Processing Record 6 of Set 2 | antigonish
# Processing Record 7 of Set 2 | ventspils
# Processing Record 8 of Set 2 | babayevo
# Processing Record 9 of Set 2 | usinsk
# Processing Record 10 of Set 2 | papatowai
# Processing Record 11 of Set 2 | la ronge
# Processing Record 12 of Set 2 | invercargill
# Processing Record 13 of Set 2 | ghormach
# Processing Record 14 of Set 2 | acapulco de juarez
# Processing Record 15 of Set 2 | mumford
# Processing Record 16 of Set 2 | whitehorse
# Processing Record 17 of Set 2 | grevena
# Processing Record 18 of Set 2 | tiksi
# Processing Record 19 of Set 2 | kaa-khem
# Processing Record 20 of Set 2 | kenitra
# Processing Record 21 of Set 2 | puerto deseado
# Processing Record 22 of Set 2 | ilulissat
# Processing Record 23 of Set 2 | palmer
# Processing Record 24 of Set 2 | ribeira grande
# Processing Record 25 of Set 2 | harpalpur
# Processing Record 26 of Set 2 | dzhalagash
# Processing Record 27 of Set 2 | bilibino
# Processing Record 28 of Set 2 | margaret river
# Processing Record 29 of Set 2 | west island
# Processing Record 30 of Set 2 | sariyahsi
# Processing Record 31 of Set 2 | elmendorf air force base
# City not found. Skipping...
# Processing Record 32 of Set 2 | port mathurin
# Processing Record 33 of Set 2 | horta
# Processing Record 34 of Set 2 | ouellah
# City not found. Skipping...
# Processing Record 35 of Set 2 | puerto natales
# Processing Record 36 of Set 2 | holualoa
# Processing Record 37 of Set 2 | codrington
# Processing Record 38 of Set 2 | sarangani
# Processing Record 39 of Set 2 | paita
# Processing Record 40 of Set 2 | camana
# Processing Record 41 of Set 2 | chibougamau
# Processing Record 42 of Set 2 | london
# Processing Record 43 of Set 2 | lazaro cardenas
# Processing Record 44 of Set 2 | puerto ayora
# Processing Record 45 of Set 2 | jamestown
# Processing Record 46 of Set 2 | songjianghe
# Processing Record 47 of Set 2 | qaqortoq
# Processing Record 48 of Set 2 | carnarvon
# Processing Record 49 of Set 2 | longyearbyen
# Processing Record 0 of Set 3 | dryden
# Processing Record 1 of Set 3 | cambria
# Processing Record 2 of Set 3 | marataizes
# Processing Record 3 of Set 3 | dawukou
# Processing Record 4 of Set 3 | obihiro
# Processing Record 5 of Set 3 | emerald
# Processing Record 6 of Set 3 | ixtapa
# Processing Record 7 of Set 3 | dalandzadgad
# City not found. Skipping...
# Processing Record 8 of Set 3 | saint-joseph
# City not found. Skipping...
# Processing Record 9 of Set 3 | sola
# Processing Record 10 of Set 3 | thompson
# Processing Record 11 of Set 3 | port lincoln
# Processing Record 12 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 13 of Set 3 | atafu village
# Processing Record 14 of Set 3 | tadine
# Processing Record 15 of Set 3 | valparaiso
# Processing Record 16 of Set 3 | fale old settlement
# Processing Record 17 of Set 3 | remire-montjoly
# Processing Record 18 of Set 3 | danielskuil
# Processing Record 19 of Set 3 | kavieng
# Processing Record 20 of Set 3 | cassilandia
# Processing Record 21 of Set 3 | igarka
# Processing Record 22 of Set 3 | metlili chaamba
# Processing Record 23 of Set 3 | east london
# Processing Record 24 of Set 3 | anna regina
# Processing Record 25 of Set 3 | yemetsk
# Processing Record 26 of Set 3 | mahibadhoo
# Processing Record 27 of Set 3 | fonte boa
# Processing Record 28 of Set 3 | hermansverk
# Processing Record 29 of Set 3 | buinsk
# Processing Record 30 of Set 3 | yaren
# Processing Record 31 of Set 3 | avarua
# Processing Record 32 of Set 3 | plettenberg bay
# Processing Record 33 of Set 3 | fada
# Processing Record 34 of Set 3 | las animas
# Processing Record 35 of Set 3 | san luis de la loma
# Processing Record 36 of Set 3 | kidal
# Processing Record 37 of Set 3 | astrakhan
# Processing Record 38 of Set 3 | segbwema
# Processing Record 39 of Set 3 | wailua homesteads
# Processing Record 40 of Set 3 | polyarnyy
# Processing Record 41 of Set 3 | porto novo
# Processing Record 42 of Set 3 | nadym
# Processing Record 43 of Set 3 | namsos
# Processing Record 44 of Set 3 | crane
# Processing Record 45 of Set 3 | nova sintra
# Processing Record 46 of Set 3 | vilyuchinsk
# Processing Record 47 of Set 3 | idri
# Processing Record 48 of Set 3 | novyy urengoy
# Processing Record 49 of Set 3 | nogliki
# Processing Record 0 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 1 of Set 4 | lompoc
# Processing Record 2 of Set 4 | tvoroyri
# Processing Record 3 of Set 4 | kodiak
# Processing Record 4 of Set 4 | khovd
# Processing Record 5 of Set 4 | egilsstadir
# Processing Record 6 of Set 4 | dudinka
# Processing Record 7 of Set 4 | punta arenas
# Processing Record 8 of Set 4 | musay'id
# City not found. Skipping...
# Processing Record 9 of Set 4 | fortuna
# Processing Record 10 of Set 4 | carutapera
# Processing Record 11 of Set 4 | vorkuta
# Processing Record 12 of Set 4 | revda
# Processing Record 13 of Set 4 | kill devil hills
# Processing Record 14 of Set 4 | vedaraniyam
# Processing Record 15 of Set 4 | callao
# Processing Record 16 of Set 4 | yashkino
# Processing Record 17 of Set 4 | barnoldswick
# Processing Record 18 of Set 4 | totnes
# Processing Record 19 of Set 4 | kirakira
# Processing Record 20 of Set 4 | diamantino
# Processing Record 21 of Set 4 | port alfred
# Processing Record 22 of Set 4 | port douglas
# Processing Record 23 of Set 4 | mpraeso
# Processing Record 24 of Set 4 | sinabang
# Processing Record 25 of Set 4 | nizhneangarsk
# Processing Record 26 of Set 4 | ar rutbah
# Processing Record 27 of Set 4 | bandon
# Processing Record 28 of Set 4 | huaraz
# Processing Record 29 of Set 4 | vail
# Processing Record 30 of Set 4 | taitung city
# Processing Record 31 of Set 4 | medicine hat
# Processing Record 32 of Set 4 | banff
# Processing Record 33 of Set 4 | malango
# Processing Record 34 of Set 4 | vastaboland
# City not found. Skipping...
# Processing Record 35 of Set 4 | arraial do cabo
# Processing Record 36 of Set 4 | yichun
# Processing Record 37 of Set 4 | georgetown
# Processing Record 38 of Set 4 | floro
# Processing Record 39 of Set 4 | hobyo
# Processing Record 40 of Set 4 | kosh-agach
# Processing Record 41 of Set 4 | north bay
# Processing Record 42 of Set 4 | klaksvik
# Processing Record 43 of Set 4 | kudahuvadhoo
# Processing Record 44 of Set 4 | oroqen zizhiqi
# Processing Record 45 of Set 4 | hami
# Processing Record 46 of Set 4 | fuvahmulah
# City not found. Skipping...
# Processing Record 47 of Set 4 | kalmar
# Processing Record 48 of Set 4 | klyuchi
# Processing Record 49 of Set 4 | tocopilla
# Processing Record 0 of Set 5 | hermanus
# Processing Record 1 of Set 5 | nosy varika
# Processing Record 2 of Set 5 | sishilichengzi
# City not found. Skipping...
# Processing Record 3 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 4 of Set 5 | brookings
# Processing Record 5 of Set 5 | bodaybo
# Processing Record 6 of Set 5 | tyre
# Processing Record 7 of Set 5 | thunder bay
# Processing Record 8 of Set 5 | shevchenko
# Processing Record 9 of Set 5 | villa gesell
# Processing Record 10 of Set 5 | akureyri
# Processing Record 11 of Set 5 | laguna
# Processing Record 12 of Set 5 | leava
# Processing Record 13 of Set 5 | ghanzi
# Processing Record 14 of Set 5 | myitkyina
# Processing Record 15 of Set 5 | ust-nera
# Processing Record 16 of Set 5 | avranches
# Processing Record 17 of Set 5 | yuzhno-kurilsk
# Processing Record 18 of Set 5 | kavaratti
# Processing Record 19 of Set 5 | kani keli
# Processing Record 20 of Set 5 | palikir - national government center
# Processing Record 21 of Set 5 | gereida
# Processing Record 22 of Set 5 | bredasdorp
# Processing Record 23 of Set 5 | olivenza
# Processing Record 24 of Set 5 | colonia
# Processing Record 25 of Set 5 | oriximina
# Processing Record 26 of Set 5 | puerto baquerizo moreno
# Processing Record 27 of Set 5 | rukungiri
# Processing Record 28 of Set 5 | helena valley southeast
# Processing Record 29 of Set 5 | waiuku
# Processing Record 30 of Set 5 | bouar
# Processing Record 31 of Set 5 | zhalantun
# Processing Record 32 of Set 5 | buka
# Processing Record 33 of Set 5 | la sarre
# Processing Record 34 of Set 5 | cat ba
# City not found. Skipping...
# Processing Record 35 of Set 5 | entebbe
# Processing Record 36 of Set 5 | nuriootpa
# Processing Record 37 of Set 5 | usogorsk
# Processing Record 38 of Set 5 | vershino-darasunskiy
# Processing Record 39 of Set 5 | tir pul
# Processing Record 40 of Set 5 | general jose de san martin
# Processing Record 41 of Set 5 | pokhara
# Processing Record 42 of Set 5 | soata
# Processing Record 43 of Set 5 | colares
# Processing Record 44 of Set 5 | susuman
# Processing Record 45 of Set 5 | kone
# Processing Record 46 of Set 5 | sal rei
# Processing Record 47 of Set 5 | sakaiminato
# Processing Record 48 of Set 5 | vingt cinq
# City not found. Skipping...
# Processing Record 49 of Set 5 | kirovsk
# Processing Record 0 of Set 6 | luderitz
# Processing Record 1 of Set 6 | namibe
# Processing Record 2 of Set 6 | tan-tan
# Processing Record 3 of Set 6 | corner brook
# Processing Record 4 of Set 6 | byndoor
# Processing Record 5 of Set 6 | buala
# Processing Record 6 of Set 6 | nykvarn
# Processing Record 7 of Set 6 | prince albert
# Processing Record 8 of Set 6 | mili
# Processing Record 9 of Set 6 | jwaneng
# Processing Record 10 of Set 6 | aswan
# Processing Record 11 of Set 6 | san juan bautista
# Processing Record 12 of Set 6 | richfield
# Processing Record 13 of Set 6 | maceio
# Processing Record 14 of Set 6 | khandyga
# Processing Record 15 of Set 6 | voinesti
# Processing Record 16 of Set 6 | ghadamis
# Processing Record 17 of Set 6 | al kharijah
# Processing Record 18 of Set 6 | ketchikan
# Processing Record 19 of Set 6 | novoishimskiy
# Processing Record 20 of Set 6 | uturoa
# Processing Record 21 of Set 6 | sonsorol village
# City not found. Skipping...
# Processing Record 22 of Set 6 | richards bay
# Processing Record 23 of Set 6 | saiha
# Processing Record 24 of Set 6 | college
# Processing Record 25 of Set 6 | kolonia
# Processing Record 26 of Set 6 | naze
# Processing Record 27 of Set 6 | brandon
# Processing Record 28 of Set 6 | ugoofaaru
# Processing Record 29 of Set 6 | kapa'a
# Processing Record 30 of Set 6 | conde
# Processing Record 31 of Set 6 | taoudenni
# Processing Record 32 of Set 6 | humberto de campos
# Processing Record 33 of Set 6 | serro
# Processing Record 34 of Set 6 | tazovsky
# Processing Record 35 of Set 6 | nayoro
# Processing Record 36 of Set 6 | xinzhou
# Processing Record 37 of Set 6 | dno
# Processing Record 38 of Set 6 | hsinchu
# Processing Record 39 of Set 6 | iskateley
# Processing Record 40 of Set 6 | ancud
# Processing Record 41 of Set 6 | tulun
# Processing Record 42 of Set 6 | cestos city
# Processing Record 43 of Set 6 | ormara
# Processing Record 44 of Set 6 | ha tinh
# Processing Record 45 of Set 6 | constantia
# Processing Record 46 of Set 6 | aykhal
# Processing Record 47 of Set 6 | novyy urgal
# Processing Record 48 of Set 6 | summerside
# Processing Record 49 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 0 of Set 7 | campbell river
# Processing Record 1 of Set 7 | sherbrooke
# Processing Record 2 of Set 7 | saldanha
# Processing Record 3 of Set 7 | villa regina
# Processing Record 4 of Set 7 | sandnessjoen
# Processing Record 5 of Set 7 | homer
# Processing Record 6 of Set 7 | patterson
# Processing Record 7 of Set 7 | coquimbo
# Processing Record 8 of Set 7 | alo
# Processing Record 9 of Set 7 | isafjordur
# Processing Record 10 of Set 7 | flying fish cove
# Processing Record 11 of Set 7 | queenstown
# Processing Record 12 of Set 7 | balikpapan
# Processing Record 13 of Set 7 | kulia village
# City not found. Skipping...
# Processing Record 14 of Set 7 | sitka
# Processing Record 15 of Set 7 | maragogi
# Processing Record 16 of Set 7 | ranau
# Processing Record 17 of Set 7 | newman
# Processing Record 18 of Set 7 | chazuta
# Processing Record 19 of Set 7 | kingston
# Processing Record 20 of Set 7 | novomyrhorod
# Processing Record 21 of Set 7 | kapoeta
# Processing Record 22 of Set 7 | kapuskasing
# Processing Record 23 of Set 7 | santa ana
# Processing Record 24 of Set 7 | boulder hill
# Processing Record 25 of Set 7 | wote
# Processing Record 26 of Set 7 | terekli-mekteb
# Processing Record 27 of Set 7 | westport
# Processing Record 28 of Set 7 | papao
# Processing Record 29 of Set 7 | sao raimundo nonato
# Processing Record 30 of Set 7 | kununurra
# Processing Record 31 of Set 7 | castillos
# Processing Record 32 of Set 7 | otwock
# Processing Record 33 of Set 7 | spanish wells
# Processing Record 34 of Set 7 | jhargram
# Processing Record 35 of Set 7 | sengkang
# Processing Record 36 of Set 7 | ifakara
# Processing Record 37 of Set 7 | plastun
# Processing Record 38 of Set 7 | sungai penuh
# Processing Record 39 of Set 7 | cheremushki
# Processing Record 40 of Set 7 | thurgoona
# Processing Record 41 of Set 7 | darwin
# Processing Record 42 of Set 7 | buerarema
# Processing Record 43 of Set 7 | monteros
# Processing Record 44 of Set 7 | kristiansund
# Processing Record 45 of Set 7 | port elizabeth
# Processing Record 46 of Set 7 | sao jose da coroa grande
# Processing Record 47 of Set 7 | mount isa
# Processing Record 48 of Set 7 | alenquer
# Processing Record 49 of Set 7 | broome
# Processing Record 0 of Set 8 | krasnyy chikoy
# Processing Record 1 of Set 8 | hasaki
# Processing Record 2 of Set 8 | san antonio de pale
# Processing Record 3 of Set 8 | mutuali
# Processing Record 4 of Set 8 | ialibu
# Processing Record 5 of Set 8 | burg auf fehmarn
# Processing Record 6 of Set 8 | roscommon
# Processing Record 7 of Set 8 | wau
# Processing Record 8 of Set 8 | geraldton
# Processing Record 9 of Set 8 | lukolela
# Processing Record 10 of Set 8 | languyan
# Processing Record 11 of Set 8 | nar'yan-mar
# Processing Record 12 of Set 8 | weno
# Processing Record 13 of Set 8 | chuzhou
# Processing Record 14 of Set 8 | port saint john's
# Processing Record 15 of Set 8 | sirre
# Processing Record 16 of Set 8 | chhatapur
# Processing Record 17 of Set 8 | mizan teferi
# Processing Record 18 of Set 8 | belyy yar
# Processing Record 19 of Set 8 | puerto aysen
# Processing Record 20 of Set 8 | la passe
# Processing Record 21 of Set 8 | gongchangling
# Processing Record 22 of Set 8 | ebon
# Processing Record 23 of Set 8 | zuwarah
# Processing Record 24 of Set 8 | pyin oo lwin
# Processing Record 25 of Set 8 | raja
# Processing Record 26 of Set 8 | midvagur
# Processing Record 27 of Set 8 | daytona beach
# Processing Record 28 of Set 8 | zhezqazghan
# Processing Record 29 of Set 8 | tindouf
# Processing Record 30 of Set 8 | yeniseysk
# Processing Record 31 of Set 8 | justo daract
# Processing Record 32 of Set 8 | kabul
# Processing Record 33 of Set 8 | sao paulo de olivenca
# Processing Record 34 of Set 8 | rio gallegos
# Processing Record 35 of Set 8 | deqen
# Processing Record 36 of Set 8 | orkney
# Processing Record 37 of Set 8 | wynyard
# Processing Record 38 of Set 8 | gizo
# Processing Record 39 of Set 8 | mogocha
# Processing Record 40 of Set 8 | katsuura
# Processing Record 41 of Set 8 | mokopane
# Processing Record 42 of Set 8 | kulhudhuffushi
# Processing Record 43 of Set 8 | belmonte
# Processing Record 44 of Set 8 | calvi
# Processing Record 45 of Set 8 | isfahan
# Processing Record 46 of Set 8 | tuba city
# Processing Record 47 of Set 8 | muang phonsavan
# Processing Record 48 of Set 8 | ishigaki
# Processing Record 49 of Set 8 | el tigre
# Processing Record 0 of Set 9 | rawson
# Processing Record 1 of Set 9 | neryungri
# Processing Record 2 of Set 9 | ofunato
# Processing Record 3 of Set 9 | svetlyy
# Processing Record 4 of Set 9 | montclair
# Processing Record 5 of Set 9 | rocha
# Processing Record 6 of Set 9 | urangan
# Processing Record 7 of Set 9 | samdrup jongkhar
# Processing Record 8 of Set 9 | shakawe
# Processing Record 9 of Set 9 | nabire
# Processing Record 10 of Set 9 | tarnogskiy gorodok
# Processing Record 11 of Set 9 | gejiu
# Processing Record 12 of Set 9 | hurricane
# Processing Record 13 of Set 9 | alice springs
# Processing Record 14 of Set 9 | karratha
# Processing Record 15 of Set 9 | kalmunai
# Processing Record 16 of Set 9 | quang ngai
# Processing Record 17 of Set 9 | la'ie
# Processing Record 18 of Set 9 | ciudad lazaro cardenas
# Processing Record 19 of Set 9 | takoradi
# Processing Record 20 of Set 9 | jabor
# Processing Record 21 of Set 9 | sehwan
# Processing Record 22 of Set 9 | sekong
# Processing Record 23 of Set 9 | beira
# Processing Record 24 of Set 9 | nagato
# Processing Record 25 of Set 9 | amga
# Processing Record 26 of Set 9 | new ross
# Processing Record 27 of Set 9 | udachny
# Processing Record 28 of Set 9 | lata
# Processing Record 29 of Set 9 | prince rupert
# Processing Record 30 of Set 9 | preobrazheniye
# Processing Record 31 of Set 9 | achacachi
# Processing Record 32 of Set 9 | ginir
# Processing Record 33 of Set 9 | fisterra
# Processing Record 34 of Set 9 | lesogorsk
# Processing Record 35 of Set 9 | caleta de carquin
# Processing Record 36 of Set 9 | bubaque
# Processing Record 37 of Set 9 | 'alaqahdari dishu
# Processing Record 38 of Set 9 | winnemucca
# Processing Record 39 of Set 9 | juneau
# Processing Record 40 of Set 9 | tromso
# Processing Record 41 of Set 9 | kyzyl-mazhalyk
# Processing Record 42 of Set 9 | norfolk
# Processing Record 43 of Set 9 | ibiruba
# Processing Record 44 of Set 9 | xining
# Processing Record 45 of Set 9 | bambanglipuro
# Processing Record 46 of Set 9 | arno
# Processing Record 47 of Set 9 | sisimiut
# Processing Record 48 of Set 9 | nili
# Processing Record 49 of Set 9 | port-cartier
# Processing Record 0 of Set 10 | omutinskiy
# Processing Record 1 of Set 10 | namdrik
# Processing Record 2 of Set 10 | pandan
# Processing Record 3 of Set 10 | thief river falls
# Processing Record 4 of Set 10 | cukai
# Processing Record 5 of Set 10 | bargaal
# Processing Record 6 of Set 10 | cairns city
# City not found. Skipping...
# Processing Record 7 of Set 10 | kowon-up
# Processing Record 8 of Set 10 | qui nhon
# Processing Record 9 of Set 10 | hamilton
# Processing Record 10 of Set 10 | hotan
# Processing Record 11 of Set 10 | san luis obispo
# Processing Record 12 of Set 10 | al mutayrifi
# Processing Record 13 of Set 10 | yangquan
# Processing Record 14 of Set 10 | laojunmiao
# Processing Record 15 of Set 10 | kamiiso
# Processing Record 16 of Set 10 | paracuru
# Processing Record 17 of Set 10 | privolzhsk
# Processing Record 18 of Set 10 | phai sali
# Processing Record 19 of Set 10 | jumla
# Processing Record 20 of Set 10 | high river
# Processing Record 21 of Set 10 | medak
# Processing Record 22 of Set 10 | siaya
# Processing Record 23 of Set 10 | gulf shores
# Processing Record 24 of Set 10 | mount pearl
# Processing Record 25 of Set 10 | dengzhou
# Processing Record 26 of Set 10 | vilhena
# Processing Record 27 of Set 10 | antsiranana
# Processing Record 28 of Set 10 | khairpur nathan shah
# Processing Record 29 of Set 10 | kiuruvesi
# Processing Record 30 of Set 10 | yelizovo
# Processing Record 31 of Set 10 | waingapu
# Processing Record 32 of Set 10 | pola de lena
# Processing Record 33 of Set 10 | guelma
# Processing Record 34 of Set 10 | aur
# Processing Record 35 of Set 10 | seogwipo
# City not found. Skipping...
# Processing Record 36 of Set 10 | jose pedro varela
# Processing Record 37 of Set 10 | shingu
# Processing Record 38 of Set 10 | azadshahr
# Processing Record 39 of Set 10 | maintirano
# Processing Record 40 of Set 10 | santa terezinha
# Processing Record 41 of Set 10 | malanje
# Processing Record 42 of Set 10 | haiku-pauwela
# Processing Record 43 of Set 10 | bourbon-lancy
# Processing Record 44 of Set 10 | mbanza-ngungu
# Processing Record 45 of Set 10 | meadow lakes
# Processing Record 46 of Set 10 | happy valley-goose bay
# Processing Record 47 of Set 10 | san martin
# Processing Record 48 of Set 10 | pasighat
# Processing Record 49 of Set 10 | cannonvale
# Processing Record 0 of Set 11 | antsirabe afovoany
# City not found. Skipping...
# Processing Record 1 of Set 11 | pangkalan brandan
# Processing Record 2 of Set 11 | port-vila
# Processing Record 3 of Set 11 | tolanaro
# Processing Record 4 of Set 11 | jose maria morelos
# Processing Record 5 of Set 11 | mata-utu
# Processing Record 6 of Set 11 | trincomalee
# Processing Record 7 of Set 11 | natal
# Processing Record 8 of Set 11 | saint-pierre
# Processing Record 9 of Set 11 | chulakkurgan
# Processing Record 10 of Set 11 | kerema
# Processing Record 11 of Set 11 | blythe
# Processing Record 12 of Set 11 | tevragh zeina
# City not found. Skipping...
# Processing Record 13 of Set 11 | dokshytsy
# Processing Record 14 of Set 11 | mount gambier
# Processing Record 15 of Set 11 | toccoa
# Processing Record 16 of Set 11 | cabo san lucas
# Processing Record 17 of Set 11 | katangi
# Processing Record 18 of Set 11 | nova vicosa
# Processing Record 19 of Set 11 | keflavik
# Processing Record 20 of Set 11 | praia da vitoria
# Processing Record 21 of Set 11 | al ghayzah
# Processing Record 22 of Set 11 | chui
# Processing Record 23 of Set 11 | puerto armuelles
# Processing Record 24 of Set 11 | miyanoura
# City not found. Skipping...
# Processing Record 25 of Set 11 | altai
# Processing Record 26 of Set 11 | champerico
# Processing Record 27 of Set 11 | newport
# Processing Record 28 of Set 11 | carauari
# Processing Record 29 of Set 11 | gadzhiyevo
# Processing Record 30 of Set 11 | kattivakkam
# Processing Record 31 of Set 11 | lodja
# Processing Record 32 of Set 11 | tura
# Processing Record 33 of Set 11 | argo
# Processing Record 34 of Set 11 | terrace
# Processing Record 35 of Set 11 | lafiagi
# Processing Record 36 of Set 11 | chilca
# Processing Record 37 of Set 11 | afaahiti
# Processing Record 38 of Set 11 | eyl
# Processing Record 39 of Set 11 | beau vallon
# Processing Record 40 of Set 11 | ruteng
# Processing Record 41 of Set 11 | pemangkat
# Processing Record 42 of Set 11 | zorgo
# Processing Record 43 of Set 11 | meadow lake
# Processing Record 44 of Set 11 | hayma'
# City not found. Skipping...
# Processing Record 45 of Set 11 | altea
# Processing Record 46 of Set 11 | rosarito
# Processing Record 47 of Set 11 | kuala belait
# Processing Record 48 of Set 11 | nushki
# Processing Record 49 of Set 11 | menongue
# Processing Record 0 of Set 12 | al jawf
# Processing Record 1 of Set 12 | padang
# Processing Record 2 of Set 12 | cill airne
# Processing Record 3 of Set 12 | puerto lempira
# Processing Record 4 of Set 12 | shihezi
# Processing Record 5 of Set 12 | grootfontein
# Processing Record 6 of Set 12 | morehead city
# Processing Record 7 of Set 12 | beyneu
# Processing Record 8 of Set 12 | port glaud
# City not found. Skipping...
# Processing Record 9 of Set 12 | acarau
# Processing Record 10 of Set 12 | linxia chengguanzhen
# Processing Record 11 of Set 12 | banda aceh
# Processing Record 12 of Set 12 | gidole
# Processing Record 13 of Set 12 | nicoya
# Processing Record 14 of Set 12 | kasongo-lunda
# Processing Record 15 of Set 12 | nagqu
# Processing Record 16 of Set 12 | akrehamn
# Processing Record 17 of Set 12 | abengourou
# Processing Record 18 of Set 12 | nueva esperanza
# Processing Record 19 of Set 12 | sussex
# Processing Record 20 of Set 12 | togur
# Processing Record 21 of Set 12 | bartica
# Processing Record 22 of Set 12 | sibay
# Processing Record 23 of Set 12 | loango
# Processing Record 24 of Set 12 | majene
# Processing Record 25 of Set 12 | dunedin
# Processing Record 26 of Set 12 | pankrushikha
# Processing Record 27 of Set 12 | trujillo
# Processing Record 28 of Set 12 | tavda
# Processing Record 29 of Set 12 | birni n konni
# Processing Record 30 of Set 12 | kralendijk
# Processing Record 31 of Set 12 | cargados carajos
# City not found. Skipping...
# Processing Record 32 of Set 12 | toktogul
# Processing Record 33 of Set 12 | helong
# Processing Record 34 of Set 12 | ladario
# Processing Record 35 of Set 12 | quesnel
# Processing Record 36 of Set 12 | ola
# Processing Record 37 of Set 12 | quellon
# Processing Record 38 of Set 12 | rovaniemi
# Processing Record 39 of Set 12 | tralee
# Processing Record 40 of Set 12 | lerwick
# Processing Record 41 of Set 12 | qamdo
# Processing Record 42 of Set 12 | kargasok
# Processing Record 43 of Set 12 | howard springs
# Processing Record 44 of Set 12 | starobin
# Processing Record 45 of Set 12 | ta`u
# Processing Record 46 of Set 12 | suva
# Processing Record 47 of Set 12 | kingisepp
# Processing Record 48 of Set 12 | odda
# Processing Record 49 of Set 12 | tianpeng
# Processing Record 0 of Set 13 | nishinoomote
# Processing Record 1 of Set 13 | touros
# Processing Record 2 of Set 13 | barra
# Processing Record 3 of Set 13 | cermik
# Processing Record 4 of Set 13 | hadibu
# Processing Record 5 of Set 13 | kolwezi
# Processing Record 6 of Set 13 | hassi messaoud
# Processing Record 7 of Set 13 | vlahita
# Processing Record 8 of Set 13 | nuuk
# Processing Record 9 of Set 13 | imperatriz
# Processing Record 10 of Set 13 | melo
# Processing Record 11 of Set 13 | mersing
# Processing Record 12 of Set 13 | broken hill
# Processing Record 13 of Set 13 | urucara
# Processing Record 14 of Set 13 | fort mcmurray
# Processing Record 15 of Set 13 | marsh harbour
# Processing Record 16 of Set 13 | cuatro cienegas de carranza
# Processing Record 17 of Set 13 | san patricio
# Processing Record 18 of Set 13 | kalemie
# Processing Record 19 of Set 13 | mont-laurier
# Processing Record 20 of Set 13 | nuku'alofa
# Processing Record 21 of Set 13 | tikhvin
# Processing Record 22 of Set 13 | zvornik
# Processing Record 23 of Set 13 | deschutes river woods
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          599
# Lat           599
# Lng           599
# Max Temp      599
# Humidity      599
# Cloudiness    599
# Wind Speed    599
# Country       599
# Date          599
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500   70.2167    277.62        83          90
# 1             bethel  41.3712  -73.4140    276.08        68           0
# 2          adamstown -25.0660 -130.1015    297.84        73          98
# 3               nadi -17.8000  177.4167    303.15        66          20
# 4               lebu -37.6167  -73.6500    288.55        85          16
#
#    Wind Speed Country        Date
# 0       17.48      TF  1704237042
# 1        1.54      US  1704237043
# 2        1.26      PN  1704237043
# 3        5.14      FJ  1704237044
# 4        8.06      CL  1704237045

# %%
# Export the City_Data into a csv
city_data_df.to_csv("/Users/demetriahorton/PythonStuff/python-api-challenge/__pycache__/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("/Users/demetriahorton/PythonStuff/python-api-challenge/__pycache__/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0  port-aux-francais -49.3500   70.2167    277.62        83
# 1        1             bethel  41.3712  -73.4140    276.08        68
# 2        2          adamstown -25.0660 -130.1015    297.84        73
# 3        3               nadi -17.8000  177.4167    303.15        66
# 4        4               lebu -37.6167  -73.6500    288.55        85
#
#    Cloudiness  Wind Speed Country        Date
# 0          90       17.48      TF  1704237042
# 1           0        1.54      US  1704237043
# 2          98        1.26      PN  1704237043
# 3          20        5.14      FJ  1704237044
# 4          16        8.06      CL  1704237045

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.xlim(-60, 80)
plt.ylim(200, 325)
plt.grid(True)


# Save the figure
plt.savefig("/Users/demetriahorton/PythonStuff/python-api-challenge/__pycache__/")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.xlim(-60, 80)
plt.ylim(0, 120)
plt.grid(True)


# Save the figure
plt.savefig("/Users/demetriahorton/PythonStuff/python-api-challenge/__pycache__/scatter_plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.xlim(-60, 80)
plt.ylim(0, 120)
plt.grid(True)

# Save the figure
plt.savefig("/Users/demetriahorton/PythonStuff/python-api-challenge/__pycache__/scatter_plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.xlim(-60, 80)
plt.ylim(0, 15)
plt.grid(True)

# Save the figure
plt.savefig("/Users/demetriahorton/PythonStuff/python-api-challenge/__pycache__/scatter_plot.png")
# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression(x, y):
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    regression_line = slope * x + intercept
    
    plt.scatter(x, y)
    plt.plot(x, regression_line, color='red')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title('Linear Regression')
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]


# Display sample data
northern_hemi_df.head()
# Out:
#    City_ID        City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 1        1      bethel  41.3712 -73.4140    276.08        68           0
# 6        6      albany  42.6001 -73.9662    273.64        78           6
# 7        7   algeciras  36.1333  -5.4505    287.97        77          68
# 8        8  hanceville  34.0607 -86.7675    281.23        62          98
# 9        9     iqaluit  63.7506 -68.5145    254.00        78         100
#
#    Wind Speed Country        Date
# 1        1.54      US  1704237043
# 6        1.36      US  1704237036
# 7        4.12      ES  1704237046
# 8        1.50      US  1704237046
# 9        8.23      CA  1704236906

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0  port-aux-francais -49.3500   70.2167    277.62        83
# 2        2          adamstown -25.0660 -130.1015    297.84        73
# 3        3               nadi -17.8000  177.4167    303.15        66
# 4        4               lebu -37.6167  -73.6500    288.55        85
# 5        5        new norfolk -42.7826  147.0587    295.77        51
#
#    Cloudiness  Wind Speed Country        Date
# 0          90       17.48      TF  1704237042
# 2          98        1.26      PN  1704237043
# 3          20        5.14      FJ  1704237044
# 4          16        8.06      CL  1704237045
# 5          79        1.00      AU  1704237045

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x = northern_hemi_df['Lat']
y = northern_hemi_df['Max Temp']

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Print the regression results
regression_line = slope * x + intercept

plt.scatter(x, y)
plt.plot(x, regression_line, color='red')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Linear Regression in the Northern Hemisphere')
plt.show()
print("R-value:", r_value)
# Out:
# R-value: -0.8367026485935735

# %%
# Linear regression on Southern Hemisphere
x = southern_hemi_df['Lat']
y = southern_hemi_df['Max Temp']

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Calculate the regression line
regression_line = slope * x + intercept

plt.scatter(x, y)
plt.plot(x, regression_line, color='red')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Linear Regression in the Southern Hemisphere')
plt.show()

# Print the regression results
print("R-value:", r_value)
# Out:
# R-value: 0.5157672330426488

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df['Lat']
y = northern_hemi_df['Humidity']

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Calculate the regression line
regression_line = slope * x + intercept

plt.scatter(x, y)
plt.plot(x, regression_line, color='red')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Linear Regression: Humidity vs. Latitude in the Northern Hemisphere')
plt.show()

# Print the regression results
print("R-value:", r_value)
# Out:
# R-value: 0.3372562732935527

# %%
# Southern Hemisphere
x = southern_hemi_df['Lat']
y = southern_hemi_df['Humidity']

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Calculate the regression line
regression_line = slope * x + intercept

plt.scatter(x, y)
plt.plot(x, regression_line, color='red')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Linear Regression: Humidity vs. Latitude in the Southern Hemisphere')
plt.show()

# Print the regression results
print("R-value:", r_value)
# Out:
# R-value: 0.3879780722402735

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df['Lat']
y = northern_hemi_df['Cloudiness']

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Calculate the regression line
regression_line = slope * x + intercept

plt.scatter(x, y)
plt.plot(x, regression_line, color='red')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Linear Regression: Cloudiness vs. Latitude in the Northern Hemisphere')
plt.show()

# Print the regression results
print("R-value:", r_value)
# Out:
# R-value: 0.23773998301283716

# %%
# Southern Hemisphere
x = southern_hemi_df['Lat']
y = southern_hemi_df['Cloudiness']

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Calculate the regression line
regression_line = slope * x + intercept

plt.scatter(x, y)
plt.plot(x, regression_line, color='red')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Linear Regression: Cloudiness vs. Latitude in the Southern Hemisphere')
plt.show()

# Print the regression results
print("R-value:", r_value)
# Out:
# R-value: 0.1892802434634636

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df['Lat']
y = northern_hemi_df['Wind Speed']

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Calculate the regression line
regression_line = slope * x + intercept

plt.scatter(x, y)
plt.plot(x, regression_line, color='red')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Linear Regression: Wind Speed vs. Latitude in the Northern Hemisphere')
plt.show()

# Print the regression results
print("R-value:", r_value)
# Out:
# R-value: 0.12476929639910042

# %%
# Southern Hemisphere
x = southern_hemi_df['Lat']
y = southern_hemi_df['Wind Speed']

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Calculate the regression line
regression_line = slope * x + intercept

plt.scatter(x, y)
plt.plot(x, regression_line, color='red')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Linear Regression: Wind Speed vs. Latitude in the Southern Hemisphere')
plt.show()

# Print the regression results
print("R-value:", r_value)
# Out:
# R-value: -0.33093114409215824

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
